# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Concatenate
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, GRU, Reshape
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint
from sklearn.model_selection import train_test_split
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor
import matplotlib.pyplot as plt

# %%
#  for reproducability
tf.random.set_seed(42)
np.random.seed(42)

# %%
def load_npy_file(file_path):
    return np.load(file_path)

# %%
def load_data_from_csv(csv_path, feature_dir):
    # loading the path to the mel-spec and gcc-phat csv files
    df = pd.read_csv(csv_path)
    display(df)

    gcc_paths = df['fea_gcc'].apply(lambda x: os.path.join(feature_dir, x)).to_numpy()
    spec_paths = df['fea_spec'].apply(lambda x: os.path.join(feature_dir, x)).to_numpy()
    y_train_loc_x = df['loc_x'].values
    y_train_loc_y = df['loc_y'].values

    def load_files(paths):
        with ThreadPoolExecutor(max_workers=8) as executor:
            return list(executor.map(np.load, paths))

    gcc_features = np.array(load_files(gcc_paths))
    spec_features = np.array(load_files(spec_paths))

    labels = df['subject_label'].to_numpy()

    return gcc_features, spec_features, labels, y_train_loc_x, y_train_loc_y

# %%
def encode_labels(labels):
    # encoding labels
    unique_labels = np.unique(labels)
    label_to_index = {label: idx for idx, label in enumerate(unique_labels)}
    encoded_labels = np.array([label_to_index[label] for label in labels])
    return encoded_labels, label_to_index

# %%
def build_crnn_model(input_shape_gcc, input_shape_spec, hidden_units, output_units, dropout_rate):
    # Input layers
    input_gcc = Input(shape=input_shape_gcc, name='input_gcc')
    input_spec = Input(shape=input_shape_spec, name='input_spec')

    # Convolutional layers for GCC features
    conv_gcc = Conv1D(filters=64, kernel_size=3, activation='relu')(input_gcc)
    conv_gcc = MaxPooling1D(pool_size=2)(conv_gcc)
    conv_gcc = Conv1D(filters=128, kernel_size=3, activation='relu')(conv_gcc)
    conv_gcc = MaxPooling1D(pool_size=2)(conv_gcc)

    # Convolutional layers for Mel-spectrogram features
    conv_spec = Conv1D(filters=64, kernel_size=3, activation='relu')(input_spec)
    conv_spec = MaxPooling1D(pool_size=2)(conv_spec)
    conv_spec = Conv1D(filters=128, kernel_size=3, activation='relu')(conv_spec)
    conv_spec = MaxPooling1D(pool_size=2)(conv_spec)

    # Concatenate the features along the feature axis
    concatenated = Concatenate(axis=-1)([conv_gcc, conv_spec])

    # Reshape the concatenated output to be compatible with GRU
    # Calculate the new timesteps and features after concatenation
    timesteps = concatenated.shape[1]  # Number of timesteps
    features = concatenated.shape[2]   # Number of features
    reshaped = Reshape((timesteps, features))(concatenated)

    # Recurrent layers
    rnn = GRU(hidden_units, return_sequences=False)(reshaped)
    rnn = Dropout(dropout_rate)(rnn)

    # Dense layers
    dense = Dense(hidden_units, activation='relu')(rnn)
    dense = Dropout(dropout_rate)(dense)

    # Output layers
    output_loc_x = Dense(1, name='output_loc_x')(dense)
    output_loc_y = Dense(1, name='output_loc_y')(dense)
    output_subject = Dense(output_units, activation='softmax', name='output_subject')(dense)

    model = Model(inputs=[input_gcc, input_spec], outputs=[output_loc_x, output_loc_y, output_subject])

    return model

# %%
feature_dir = "/content/drive/MyDrive/FYP/data/audio_feature"  # dir containing the .npy feature files
csv_train_path = "/content/drive/MyDrive/FYP/data/audio_feature/AFPILD_FE1_rd_train.csv"  # path to the training CSV file
csv_test_path = "/content/drive/MyDrive/FYP/data/audio_feature/AFPILD_FE1_rd_test.csv"  # path to the test CSV file

# %%
batch_size=10
epochs=1
lr=0.001

# %%
log_dir = os.path.join("logs", datetime.now().strftime("%Y%m%d-%H%M%S"))
os.makedirs(log_dir, exist_ok=True)  # Ensure this directory is created
print("Log directory:", log_dir)
# Out:
# Log directory: logs/20250306-180858

# %%
# loading training data
train_gcc, train_spec, train_labels, y_train_loc_x, y_train_loc_y = load_data_from_csv(csv_train_path, feature_dir)
train_labels, label_to_index = encode_labels(train_labels)
# Out:
#       Unnamed: 0                                 fea_spec  \
# 0              0  spec/afpild_fe1_s10_3_melspec_14647.npy
# 1              1   spec/afpild_fe1_s03_4_melspec_4423.npy
# 2              2   spec/afpild_fe1_s07_1_melspec_9453.npy
# 3              3   spec/afpild_fe1_s02_1_melspec_1864.npy
# 4              4  spec/afpild_fe1_s10_1_melspec_14058.npy
# ...          ...                                      ...
# 7640        7640   spec/afpild_fe1_s03_2_melspec_3671.npy
# 7641        7641   spec/afpild_fe1_s02_4_melspec_3066.npy
# 7642        7642   spec/afpild_fe1_s06_4_melspec_9148.npy
# 7643        7643   spec/afpild_fe1_s05_3_melspec_7401.npy
# 7644        7644  spec/afpild_fe1_s10_2_melspec_14313.npy
#
#                                      fea_gcc  loc_azimuth     loc_x     loc_y  \
# 0     gcc/afpild_fe1_s10_3_gccphat_14647.npy   -60.950540  1.220343 -2.197082
# 1      gcc/afpild_fe1_s03_4_gccphat_4423.npy  -154.491737 -2.260692 -1.078695
# 2      gcc/afpild_fe1_s07_1_gccphat_9453.npy    38.618597  2.106657  1.682842
# 3      gcc/afpild_fe1_s02_1_gccphat_1864.npy   -85.188679  0.182055 -2.162911
# 4     gcc/afpild_fe1_s10_1_gccphat_14058.npy    57.953284  1.468105  2.345202
# ...                                      ...          ...       ...       ...
# 7640   gcc/afpild_fe1_s03_2_gccphat_3671.npy   135.174471 -1.706765  1.696402
# 7641   gcc/afpild_fe1_s02_4_gccphat_3066.npy   104.219056 -0.618445  2.440658
# 7642   gcc/afpild_fe1_s06_4_gccphat_9148.npy   142.471422 -2.232066  1.714494
# 7643   gcc/afpild_fe1_s05_3_gccphat_7401.npy    18.412090  2.435140  0.810634
# 7644  gcc/afpild_fe1_s10_2_gccphat_14313.npy   -42.683269  2.122698 -1.957622
#
#      subject_label
# 0              S10
# 1              S03
# 2              S07
# 3              S02
# 4              S10
# ...            ...
# 7640           S03
# 7641           S02
# 7642           S06
# 7643           S05
# 7644           S10
#
# [7645 rows x 7 columns]

# %%
# loading test data
test_gcc, test_spec, test_labels, y_test_loc_x, y_test_loc_y = load_data_from_csv(csv_test_path, feature_dir)
test_labels = np.array([label_to_index[label] for label in test_labels])
# Out:
#       Unnamed: 0                                 fea_spec  \
# 0              0  spec/afpild_fe1_s07_2_melspec_10032.npy
# 1              1    spec/afpild_fe1_s01_2_melspec_694.npy
# 2              2   spec/afpild_fe1_s01_4_melspec_1353.npy
# 3              3   spec/afpild_fe1_s02_2_melspec_2192.npy
# 4              4   spec/afpild_fe1_s03_3_melspec_4320.npy
# ...          ...                                      ...
# 7640        7640   spec/afpild_fe1_s05_1_melspec_6374.npy
# 7641        7641   spec/afpild_fe1_s02_3_melspec_2313.npy
# 7642        7642   spec/afpild_fe1_s02_4_melspec_3047.npy
# 7643        7643   spec/afpild_fe1_s04_4_melspec_6005.npy
# 7644        7644  spec/afpild_fe1_s08_2_melspec_11265.npy
#
#                                      fea_gcc  loc_azimuth     loc_x     loc_y  \
# 0     gcc/afpild_fe1_s07_2_gccphat_10032.npy  -163.534055 -2.488816 -0.735612
# 1       gcc/afpild_fe1_s01_2_gccphat_694.npy  -118.879613 -1.201399 -2.178162
# 2      gcc/afpild_fe1_s01_4_gccphat_1353.npy   165.728483 -2.503814  0.636889
# 3      gcc/afpild_fe1_s02_2_gccphat_2192.npy   140.908809 -2.245858  1.824586
# 4      gcc/afpild_fe1_s03_3_gccphat_4320.npy  -135.872432 -1.913522 -1.856118
# ...                                      ...          ...       ...       ...
# 7640   gcc/afpild_fe1_s05_1_gccphat_6374.npy  -128.619019 -1.709304 -2.139751
# 7641   gcc/afpild_fe1_s02_3_gccphat_2313.npy   168.723426 -2.281209  0.454861
# 7642   gcc/afpild_fe1_s02_4_gccphat_3047.npy   -17.853105  2.482435 -0.799562
# 7643   gcc/afpild_fe1_s04_4_gccphat_6005.npy    22.512584  2.305999  0.955770
# 7644  gcc/afpild_fe1_s08_2_gccphat_11265.npy   -27.775972  2.167231 -1.141490
#
#      subject_label
# 0              S07
# 1              S01
# 2              S01
# 3              S02
# 4              S03
# ...            ...
# 7640           S05
# 7641           S02
# 7642           S02
# 7643           S04
# 7644           S08
#
# [7645 rows x 7 columns]

# %%
# Reshape data to match CRNN input shape
train_gcc = train_gcc.reshape(train_gcc.shape[0], train_gcc.shape[1], -1)  # Shape: (None, 64, 64*6)
test_gcc = test_gcc.reshape(test_gcc.shape[0], test_gcc.shape[1], -1)  # Shape: (None, 64, 64*6)
train_spec = train_spec.reshape(train_spec.shape[0], train_spec.shape[1], -1)  # Shape: (None, 64, 64*4)
test_spec = test_spec.reshape(test_spec.shape[0], test_spec.shape[1], -1)  # Shape: (None, 64, 64*4)

# %%
X_train_gcc, X_val_gcc, X_train_spec, X_val_spec, y_train, y_val, y_train_loc_x_tr, y_train_loc_x_val, y_train_loc_y_tr, y_train_loc_y_val  = train_test_split(
    train_gcc, train_spec, train_labels, y_train_loc_x, y_train_loc_y, test_size=0.2, random_state=42
)

# %%
# Check shapes of loaded data
print("Train GCC shape:", train_gcc.shape)
print("Train Spec shape:", train_spec.shape)
print("Train labels shape:", train_labels.shape)
print("Test GCC shape:", test_gcc.shape)
print("Test Spec shape:", test_spec.shape)
print("Test labels shape:", test_labels.shape)
# Out:
# Train GCC shape: (7645, 64, 384)
# Train Spec shape: (7645, 64, 256)
# Train labels shape: (7645,)
# Test GCC shape: (7645, 64, 384)
# Test Spec shape: (7645, 64, 256)
# Test labels shape: (7645,)

# %%
# Check input shapes
print("Input shape for GCC:", (X_train_gcc.shape[1], X_train_gcc.shape[2]))
print("Input shape for Spec:", (X_train_spec.shape[1], X_train_spec.shape[2]))
# Out:
# Input shape for GCC: (64, 384)
# Input shape for Spec: (64, 256)

# %%
model = build_crnn_model(
    input_shape_gcc=(X_train_gcc.shape[1], X_train_gcc.shape[2]),
    input_shape_spec=(X_train_spec.shape[1], X_train_spec.shape[2]),
    hidden_units=128,
    output_units=output_units,
    dropout_rate=0.2
)

# Print model summary
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_gcc (InputLayer)    │ (None, 64, 384)        │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_spec (InputLayer)   │ (None, 64, 256)        │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_24 (Conv1D)        │ (None, 62, 64)         │         73,792 │ input_gcc[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_26 (Conv1D)        │ (None, 62, 64)         │         49,216 │ input_spec[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling1d_24          │ (None, 31, 64)         │              0 │ conv1d_24[0][0]        │
# │ (MaxPooling1D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling1d_26          │ (None, 31, 64)         │              0 │ conv1d_26[0][0]        │
# │ (MaxPooling1D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_25 (Conv1D)        │ (None, 29, 128)        │         24,704 │ max_pooling1d_24[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_27 (Conv1D)        │ (None, 29, 128)        │         24,704 │ max_pooling1d_26[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling1d_25          │ (None, 14, 128)        │              0 │ conv1d_25[0][0]        │
# │ (MaxPooling1D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling1d_27          │ (None, 14, 128)        │              0 │ conv1d_27[0][0]        │
# │ (MaxPooling1D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_6             │ (None, 14, 256)        │              0 │ max_pooling1d_25[0][0… │
# │ (Concatenate)             │                        │                │ max_pooling1d_27[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_3 (Reshape)       │ (None, 14, 256)        │              0 │ concatenate_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gru_4 (GRU)               │ (None, 128)            │        148,224 │ reshape_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_6 (Dropout)       │ (None, 128)            │              0 │ gru_4[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 128)            │         16,512 │ dropout_6[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_7 (Dropout)       │ (None, 128)            │              0 │ dense_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output_loc_x (Dense)      │ (None, 1)              │            129 │ dropout_7[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output_loc_y (Dense)      │ (None, 1)              │            129 │ dropout_7[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output_subject (Dense)    │ (None, 10)             │          1,290 │ dropout_7[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 338,700 (1.29 MB)
#  Trainable params: 338,700 (1.29 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss={
        'output_loc_x': 'mse',
        'output_loc_y': 'mse',
        'output_subject': 'sparse_categorical_crossentropy'  # Use this for integer labels
    },
    metrics={
        'output_loc_x': 'mae',
        'output_loc_y': 'mae',
        'output_subject': 'accuracy'
    }
)

# %%
X_train_gcc, X_val_gcc, X_train_spec, X_val_spec, y_train, y_val, y_train_loc_x_tr, y_train_loc_x_val, y_train_loc_y_tr, y_train_loc_y_val = train_test_split(
    train_gcc, train_spec, train_labels, y_train_loc_x, y_train_loc_y, test_size=0.2, random_state=42
)

# %%
checkpoint_callback = ModelCheckpoint(
    filepath=os.path.join(log_dir, 'best_model.h5'),  # Ensure this path is valid
    monitor='val_accuracy',
    save_best_only=True,
    mode='max'
)

# %%
y_train_one_hot = tf.keras.utils.to_categorical(y_train, num_classes=output_units)

# %%
history = model.fit(
    [X_train_gcc, X_train_spec],
    {
        'output_loc_x': y_train_loc_x_tr,
        'output_loc_y': y_train_loc_y_tr,
        'output_subject': y_train_one_hot  # Use one-hot encoded labels
    },
    epochs=1,
    batch_size=10,
    validation_split=0.2,
    callbacks=[tensorboard_callback, checkpoint_callback]
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-72556bb78f58> in <cell line: 0>()
# ----> 1 history = model.fit(
#       2     [X_train_gcc, X_train_spec],
#       3     {
#       4         'output_loc_x': y_train_loc_x_tr,
#       5         'output_loc_y': y_train_loc_y_tr,
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/nn.py in sparse_categorical_crossentropy(target, output, from_logits, axis)
#     723         )
#     724     if len(target.shape) != len(output.shape[:-1]):
# --> 725         raise ValueError(
#     726             "Argument `output` must have rank (ndim) `target.ndim - 1`. "
#     727             "Received: "
#
# ValueError: Argument `output` must have rank (ndim) `target.ndim - 1`. Received: target.shape=(None, 10), output.shape=(None, 10)

# %%
# Evaluate the model
test_results = model.evaluate(
    [test_gcc, test_spec],
    {
        'output_loc_x': y_test_loc_x,
        'output_loc_y': y_test_loc_y,
        'output_subject': tf.keras.utils.to_categorical(test_labels, num_classes=output_units)
    },
    verbose=2
)

# Get the accuracy for the 'output_subject' output
subject_accuracy = test_results[3]  # Accuracy is usually the 4th element (index 3)
